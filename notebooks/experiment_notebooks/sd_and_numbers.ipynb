# %%
# Подключаем библиотеки
import os
os.chdir("..")

from compiled_wrapper import scidi_wrapper

import pandas
import numpy as np
import json
import random
import time 
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
# Загружаем данные с одинарным шумом
data = pandas.read_csv('test_data/numbers/digits+noise.csv', header=None)
data = data[data.columns[:-1]]
# Преобразуем в строку (оболочка работает пока только со строковым представлением)
str_data = data.values.astype(str)
print str_data[:5]
# Out:
# [['6' '2' '2' '7' '5' '1' '1' '3' '5' '1' '1' '3' '5' '1' '1' '3' '5' '8'
#   '1' '3' '7' '4' '4' '6']
#  ['6' '2' '2' '7' '5' '1' '1' '8' '5' '1' '1' '3' '5' '1' '1' '3' '5' '1'
#   '1' '3' '7' '4' '4' '6']
#  ['6' '2' '2' '7' '5' '1' '1' '3' '5' '1' '1' '3' '5' '1' '1' '3' '5' '1'
#   '1' '3' '7' '8' '4' '6']
#  ['6' '2' '2' '7' '5' '1' '1' '3' '8' '1' '1' '3' '5' '1' '1' '3' '5' '1'
#   '1' '3' '7' '4' '4' '6']
#  ['6' '2' '8' '7' '5' '1' '1' '3' '5' '1' '1' '3' '5' '1' '1' '3' '5' '1'
#   '1' '3' '7' '4' '4' '6']]

# %% [markdown]
# In this task we need rules with negetion. There are no negation in sd library so we need to simulate it with dummy predicates.

# %%
# Amount of dummy cols we need:
print len(str_data[0]) * 8
# Out:
# 192

# %%
# function for dummy negation
def addDummyNegations(item):
    new_item = list(item)
    for i in range(len(item)):
        for j in range(1, 9):
            if item[i] != str(j):
                new_item.append('n'+ str(i) + '_' + str(j))
            else:
                new_item.append('n'+ str(i) + '_' + str(j))
    return new_item

# %%
# Let's generate dummy negation data
data_with_negations = np.array([addDummyNegations(x) for x in str_data])

# %%
# Now we have 216 attributes! That is bad 
data_with_negations.shape
# Out:
# (360, 216)

# %%
# Nevertheless, let's generate rules!
sw = scidi_wrapper.ScidiWrapper()

# %%
# %%time
sw.setData(data_with_negations[:])
sw.makeRulesWithSDGenerator(3, 0.5, 1, 0.6)
rules = sw.getRules()
print len(rules)
print max([len(r) for r in rules])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-9-0840e4b0b462> in <module>()
# ----> 1 get_ipython().run_cell_magic(u'time', u'', u'sw.setData(data_with_negations[:])\nsw.makeRulesWithSDGenerator(3, 0.5, 1, 0.6)\nrules = sw.getRules()\nprint len(rules)\nprint max([len(r) for r in rules])')
#
# /home/happyuser/.local/lib/python2.7/site-packages/IPython/core/interactiveshell.pyc in run_cell_magic(self, magic_name, line, cell)
#    2291             magic_arg_s = self.var_expand(line, stack_depth)
#    2292             with self.builtin_trap:
# -> 2293                 result = fn(magic_arg_s, cell)
#    2294             return result
#    2295
#
# /home/happyuser/.local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#
# /home/happyuser/.local/lib/python2.7/site-packages/IPython/core/magic.pyc in <lambda>(f, *a, **k)
#     191     # but it's overkill for just that one bit of state.
#     192     def magic_deco(arg):
# --> 193         call = lambda f, *a, **k: f(*a, **k)
#     194
#     195         if callable(arg):
#
# /home/happyuser/.local/lib/python2.7/site-packages/IPython/core/magics/execution.pyc in time(self, line, cell, local_ns)
#    1165         else:
#    1166             st = clock2()
# -> 1167             exec(code, glob, local_ns)
#    1168             end = clock2()
#    1169             out = None
#
# <timed exec> in <module>()
#
# /home/happyuser/natural_classification/notebooks/compiled_wrapper/scidi_wrapper.pyc in makeRulesWithSDGenerator(self, *args)
#     302     def getFisher(self): return _scidi_wrapper.ScidiWrapper_getFisher(self)
#     303     def getYule(self): return _scidi_wrapper.ScidiWrapper_getYule(self)
# --> 304     def makeRulesWithSDGenerator(self, *args): return _scidi_wrapper.ScidiWrapper_makeRulesWithSDGenerator(self, *args)
#     305     def setRulesFromStringVector(self, *args): return _scidi_wrapper.ScidiWrapper_setRulesFromStringVector(self, *args)
#     306     def __init__(self):
#
# KeyboardInterrupt:

# %%
rules
# Out:
# ('17=1 => 16=5',
#  '18=6 => 16=5',
#  '18=8 => 16=5',
#  '19=3 => 16=5',
#  '19=1 => 16=5',
#  '20=8 => 16=5',
#  '20=1 & 21=6 => 16=5',
#  '20=5 => 16=5',
#  '21=8 => 16=5',
#  '21=1 => 16=5',
#  '22=4 => 16=5',
#  '23=1 => 16=5',
#  '24=1 => 16=5',
#  '24=5 => 16=5',
#  '25=n0_1 => 16=5',
#  '26=n0_2 => 16=5',
#  '27=n0_3 => 16=5',
#  '28=n0_4 => 16=5',
#  '29=n0_5 => 16=5',
#  '30=n0_6 => 16=5',
#  '31=n0_7 => 16=5',
#  '32=n0_8 => 16=5',
#  '33=n1_1 => 16=5',
#  '34=n1_2 => 16=5',
#  '35=n1_3 => 16=5',
#  '36=n1_4 => 16=5',
#  '37=n1_5 => 16=5',
#  '38=n1_6 => 16=5',
#  '39=n1_7 => 16=5',
#  '16=5 => 17=1',
#  '16=5 & 18=1 => 17=1',
#  '16=5 & 19=8 => 17=1',
#  '16=5 & 20=1 => 17=1',
#  '16=5 & 21=6 => 17=1',
#  '16=5 & 22=4 => 17=1',
#  '16=5 & 23=4 => 17=1',
#  '16=5 & 24=5 => 17=1',
#  '18=1 => 17=1',
#  '19=8 => 17=1',
#  '20=1 => 17=1',
#  '20=1 & 21=6 => 17=1',
#  '21=6 => 17=1',
#  '21=6 & 22=4 => 17=1',
#  '21=6 & 23=4 => 17=1',
#  '21=6 & 24=5 => 17=1',
#  '22=4 => 17=1',
#  '23=4 => 17=1',
#  '23=4 & 25=n0_1 => 17=1',
#  '23=4 & 26=n0_2 => 17=1',
#  '23=4 & 27=n0_3 => 17=1',
#  '23=4 & 28=n0_4 => 17=1',
#  '23=4 & 29=n0_5 => 17=1',
#  '23=4 & 30=n0_6 => 17=1',
#  '23=4 & 31=n0_7 => 17=1',
#  '23=4 & 32=n0_8 => 17=1',
#  '23=4 & 33=n1_1 => 17=1',
#  '23=4 & 34=n1_2 => 17=1',
#  '23=4 & 35=n1_3 => 17=1',
#  '23=4 & 36=n1_4 => 17=1',
#  '23=4 & 37=n1_5 => 17=1',
#  '23=4 & 38=n1_6 => 17=1',
#  '23=4 & 39=n1_7 => 17=1',
#  '24=5 => 17=1',
#  '25=n0_1 => 17=1',
#  '26=n0_2 => 17=1',
#  '27=n0_3 => 17=1',
#  '28=n0_4 => 17=1',
#  '29=n0_5 => 17=1',
#  '30=n0_6 => 17=1',
#  '31=n0_7 => 17=1',
#  '32=n0_8 => 17=1',
#  '33=n1_1 => 17=1',
#  '34=n1_2 => 17=1',
#  '35=n1_3 => 17=1',
#  '36=n1_4 => 17=1',
#  '37=n1_5 => 17=1',
#  '38=n1_6 => 17=1',
#  '39=n1_7 => 17=1',
#  '18=1 => 17=8',
#  '19=8 => 17=8',
#  '20=1 => 17=8',
#  '20=1 & 21=6 => 17=8',
#  '21=6 => 17=8',
#  '21=6 & 23=4 => 17=8',
#  '21=6 & 24=5 => 17=8',
#  '22=4 => 17=8',
#  '23=4 => 17=8',
#  '23=4 & 25=n0_1 => 17=8',
#  '23=4 & 26=n0_2 => 17=8',
#  '23=4 & 27=n0_3 => 17=8',
#  '23=4 & 28=n0_4 => 17=8',
#  '23=4 & 29=n0_5 => 17=8',
#  '23=4 & 30=n0_6 => 17=8',
#  '23=4 & 31=n0_7 => 17=8',
#  '23=4 & 32=n0_8 => 17=8',
#  '23=4 & 33=n1_1 => 17=8',
#  '23=4 & 34=n1_2 => 17=8',
#  '23=4 & 35=n1_3 => 17=8',
#  '23=4 & 36=n1_4 => 17=8',
#  '23=4 & 37=n1_5 => 17=8',
#  '23=4 & 38=n1_6 => 17=8',
#  '23=4 & 39=n1_7 => 17=8',
#  '24=5 => 17=8',
#  '25=n0_1 => 17=8',
#  '26=n0_2 => 17=8',
#  '27=n0_3 => 17=8',
#  '28=n0_4 => 17=8',
#  '29=n0_5 => 17=8',
#  '30=n0_6 => 17=8',
#  '31=n0_7 => 17=8',
#  '32=n0_8 => 17=8',
#  '33=n1_1 => 17=8',
#  '34=n1_2 => 17=8',
#  '35=n1_3 => 17=8',
#  '36=n1_4 => 17=8',
#  '37=n1_5 => 17=8',
#  '38=n1_6 => 17=8',
#  '39=n1_7 => 17=8',
#  '16=5 => 18=6',
#  '16=5 & 21=8 => 18=6',
#  '16=5 & 22=1 => 18=6',
#  '16=5 & 23=1 => 18=6',
#  '16=5 & 24=1 => 18=6',
#  '19=3 => 18=6',
#  '20=8 => 18=6',
#  '21=8 => 18=6',
#  '22=1 => 18=6',
#  '23=1 => 18=6',
#  '24=1 => 18=6',
#  '25=n0_1 => 18=6',
#  '26=n0_2 => 18=6',
#  '27=n0_3 => 18=6',
#  '28=n0_4 => 18=6',
#  '29=n0_5 => 18=6',
#  '30=n0_6 => 18=6',
#  '31=n0_7 => 18=6',
#  '32=n0_8 => 18=6',
#  '33=n1_1 => 18=6',
#  '34=n1_2 => 18=6',
#  '35=n1_3 => 18=6',
#  '36=n1_4 => 18=6',
#  '37=n1_5 => 18=6',
#  '38=n1_6 => 18=6',
#  '39=n1_7 => 18=6',
#  '16=5 & 20=1 => 18=1',
#  '16=5 & 21=6 => 18=1',
#  '17=8 => 18=1',
#  '17=8 & 20=1 => 18=1',
#  '17=8 & 21=6 => 18=1',
#  '17=1 => 18=1',
#  '17=1 & 20=1 => 18=1',
#  '17=1 & 21=6 => 18=1',
#  '19=8 => 18=1',
#  '20=1 => 18=1',
#  '20=1 & 21=6 => 18=1',
#  '20=1 & 22=4 => 18=1',
#  '20=1 & 23=8 => 18=1',
#  '20=1 & 23=4 => 18=1',
#  '20=1 & 24=4 => 18=1',
#  '20=1 & 24=5 => 18=1',
#  '21=6 => 18=1',
#  '21=6 & 22=4 => 18=1',
#  '21=6 & 23=4 => 18=1',
#  '21=6 & 24=5 => 18=1',
#  '22=4 => 18=1',
#  '23=4 => 18=1',
#  '23=4 & 25=n0_1 => 18=1',
#  '23=4 & 26=n0_2 => 18=1',
#  '23=4 & 27=n0_3 => 18=1',
#  '23=4 & 28=n0_4 => 18=1',
#  '23=4 & 29=n0_5 => 18=1',
#  '23=4 & 30=n0_6 => 18=1',
#  '23=4 & 31=n0_7 => 18=1',
#  '23=4 & 32=n0_8 => 18=1',
#  '23=4 & 33=n1_1 => 18=1',
#  '23=4 & 34=n1_2 => 18=1',
#  '23=4 & 35=n1_3 => 18=1',
#  '23=4 & 36=n1_4 => 18=1',
#  '23=4 & 37=n1_5 => 18=1',
#  '23=4 & 38=n1_6 => 18=1',
#  '23=4 & 39=n1_7 => 18=1',
#  '24=5 => 18=1',
#  '25=n0_1 => 18=1',
#  '26=n0_2 => 18=1',
#  '27=n0_3 => 18=1',
#  '28=n0_4 => 18=1',
#  '29=n0_5 => 18=1',
#  '30=n0_6 => 18=1',
#  '31=n0_7 => 18=1',
#  '32=n0_8 => 18=1',
#  '33=n1_1 => 18=1',
#  '34=n1_2 => 18=1',
#  '35=n1_3 => 18=1',
#  '36=n1_4 => 18=1',
#  '37=n1_5 => 18=1',
#  '38=n1_6 => 18=1',
#  '39=n1_7 => 18=1',
#  '16=5 => 18=8',
#  '16=5 & 19=1 => 18=8',
#  '16=5 & 20=5 => 18=8',
#  '16=5 & 21=1 => 18=8',
#  '17=1 & 19=1 => 18=8',
#  '17=1 & 20=5 => 18=8',
#  '17=1 & 21=1 => 18=8',
#  '19=1 => 18=8',
#  '20=5 => 18=8',
#  '21=1 => 18=8',
#  '23=1 => 18=8',
#  '24=1 => 18=8',
#  '25=n0_1 => 18=8',
#  '26=n0_2 => 18=8',
#  '27=n0_3 => 18=8',
#  '28=n0_4 => 18=8',
#  '29=n0_5 => 18=8',
#  '30=n0_6 => 18=8',
#  '31=n0_7 => 18=8',
#  '32=n0_8 => 18=8',
#  '33=n1_1 => 18=8',
#  '34=n1_2 => 18=8',
#  '35=n1_3 => 18=8',
#  '36=n1_4 => 18=8',
#  '37=n1_5 => 18=8',
#  '38=n1_6 => 18=8',
#  '39=n1_7 => 18=8',
#  '16=5 => 19=1',
#  '18=8 => 19=1',
#  '20=5 => 19=1',
#  '21=1 => 19=1',
#  '23=1 => 19=1',
#  '24=1 => 19=1',
#  '25=n0_1 => 19=1',
#  '26=n0_2 => 19=1',
#  '27=n0_3 => 19=1',
#  '28=n0_4 => 19=1',
#  '29=n0_5 => 19=1',
#  '30=n0_6 => 19=1',
#  '31=n0_7 => 19=1',
#  '32=n0_8 => 19=1',
#  '33=n1_1 => 19=1',
#  '34=n1_2 => 19=1',
#  '35=n1_3 => 19=1',
#  '36=n1_4 => 19=1',
#  '37=n1_5 => 19=1',
#  '38=n1_6 => 19=1',
#  '39=n1_7 => 19=1',
#  '16=5 => 19=3',
#  '16=5 & 21=8 => 19=3',
#  '16=5 & 22=1 => 19=3',
#  '16=5 & 23=1 => 19=3',
#  '16=5 & 24=1 => 19=3',
#  '18=6 => 19=3',
#  '20=8 => 19=3',
#  '21=8 => 19=3',
#  '22=1 => 19=3',
#  '23=1 => 19=3',
#  '24=1 => 19=3',
#  '25=n0_1 => 19=3',
#  '26=n0_2 => 19=3',
#  '27=n0_3 => 19=3',
#  '28=n0_4 => 19=3',
#  '29=n0_5 => 19=3',
#  '30=n0_6 => 19=3',
#  '31=n0_7 => 19=3',
#  '32=n0_8 => 19=3',
#  '33=n1_1 => 19=3',
#  '34=n1_2 => 19=3',
#  '35=n1_3 => 19=3',
#  '36=n1_4 => 19=3',
#  '37=n1_5 => 19=3',
#  '38=n1_6 => 19=3',
#  '39=n1_7 => 19=3',
#  '16=5 & 20=1 => 19=8',
#  '16=5 & 21=6 => 19=8',
#  '17=8 => 19=8',
#  '17=8 & 20=1 => 19=8',
#  '17=8 & 21=6 => 19=8',
#  '17=1 => 19=8',
#  '17=1 & 20=1 => 19=8',
#  '17=1 & 21=6 => 19=8',
#  '18=1 => 19=8',
#  '20=1 => 19=8',
#  '20=1 & 21=6 => 19=8',
#  '20=1 & 22=4 => 19=8',
#  '20=1 & 23=8 => 19=8',
#  '20=1 & 23=4 => 19=8',
#  '20=1 & 24=4 => 19=8',
#  '20=1 & 24=5 => 19=8',
#  '21=6 => 19=8',
#  '21=6 & 22=4 => 19=8',
#  '21=6 & 23=4 => 19=8',
#  '21=6 & 24=5 => 19=8',
#  '22=4 => 19=8',
#  '23=4 => 19=8',
#  '23=4 & 25=n0_1 => 19=8',
#  '23=4 & 26=n0_2 => 19=8',
#  '23=4 & 27=n0_3 => 19=8',
#  '23=4 & 28=n0_4 => 19=8',
#  '23=4 & 29=n0_5 => 19=8',
#  '23=4 & 30=n0_6 => 19=8',
#  '23=4 & 31=n0_7 => 19=8',
#  '23=4 & 32=n0_8 => 19=8',
#  '23=4 & 33=n1_1 => 19=8',
#  '23=4 & 34=n1_2 => 19=8',
#  '23=4 & 35=n1_3 => 19=8',
#  '23=4 & 36=n1_4 => 19=8',
#  '23=4 & 37=n1_5 => 19=8',
#  '23=4 & 38=n1_6 => 19=8',
#  '23=4 & 39=n1_7 => 19=8',
#  '24=5 => 19=8',
#  '25=n0_1 => 19=8',
#  '26=n0_2 => 19=8',
#  '27=n0_3 => 19=8',
#  '28=n0_4 => 19=8',
#  '29=n0_5 => 19=8',
#  '30=n0_6 => 19=8',
#  '31=n0_7 => 19=8',
#  '32=n0_8 => 19=8',
#  '33=n1_1 => 19=8',
#  '34=n1_2 => 19=8',
#  '35=n1_3 => 19=8',
#  '36=n1_4 => 19=8',
#  '37=n1_5 => 19=8',
#  '38=n1_6 => 19=8',
#  '39=n1_7 => 19=8',
#  '16=5 => 20=5',
#  '18=8 => 20=5',
#  '19=1 => 20=5',
#  '21=1 => 20=5',
#  '23=1 => 20=5',
#  '24=1 => 20=5',
#  '25=n0_1 => 20=5',
#  '26=n0_2 => 20=5',
#  '27=n0_3 => 20=5',
#  '28=n0_4 => 20=5',
#  '29=n0_5 => 20=5',
#  '30=n0_6 => 20=5',
#  '31=n0_7 => 20=5',
#  '32=n0_8 => 20=5',
#  '33=n1_1 => 20=5',
#  '34=n1_2 => 20=5',
#  '35=n1_3 => 20=5',
#  '36=n1_4 => 20=5',
#  '37=n1_5 => 20=5',
#  '38=n1_6 => 20=5',
#  '39=n1_7 => 20=5',
#  '16=5 & 21=6 => 20=1',
#  '17=8 => 20=1',
#  '17=8 & 21=6 => 20=1',
#  '17=1 => 20=1',
#  '17=1 & 21=6 => 20=1',
#  '18=1 => 20=1',
#  '19=8 => 20=1',
#  '21=6 => 20=1',
#  '21=6 & 22=4 => 20=1',
#  '21=6 & 23=4 => 20=1',
#  '21=6 & 24=5 => 20=1',
#  '22=4 => 20=1',
#  '23=4 => 20=1',
#  '23=4 & 25=n0_1 => 20=1',
#  '23=4 & 26=n0_2 => 20=1',
#  '23=4 & 27=n0_3 => 20=1',
#  '23=4 & 28=n0_4 => 20=1',
#  '23=4 & 29=n0_5 => 20=1',
#  '23=4 & 30=n0_6 => 20=1',
#  '23=4 & 31=n0_7 => 20=1',
#  '23=4 & 32=n0_8 => 20=1',
#  '23=4 & 33=n1_1 => 20=1',
#  '23=4 & 34=n1_2 => 20=1',
#  '23=4 & 35=n1_3 => 20=1',
#  '23=4 & 36=n1_4 => 20=1',
#  '23=4 & 37=n1_5 => 20=1',
#  '23=4 & 38=n1_6 => 20=1',
#  '23=4 & 39=n1_7 => 20=1',
#  '24=5 => 20=1',
#  '25=n0_1 => 20=1',
#  '26=n0_2 => 20=1',
#  '27=n0_3 => 20=1',
#  '28=n0_4 => 20=1',
#  '29=n0_5 => 20=1',
#  '30=n0_6 => 20=1',
#  '31=n0_7 => 20=1',
#  '32=n0_8 => 20=1',
#  '33=n1_1 => 20=1',
#  '34=n1_2 => 20=1',
#  '35=n1_3 => 20=1',
#  '36=n1_4 => 20=1',
#  '37=n1_5 => 20=1',
#  '38=n1_6 => 20=1',
#  '39=n1_7 => 20=1',
#  '21=6 & 22=1 => 20=3',
#  '21=6 & 22=8 => 20=3',
#  '21=7 => 20=3',
#  '22=1 => 20=3',
#  '23=3 => 20=3',
#  '24=8 => 20=3',
#  '16=5 => 20=8',
#  '16=5 & 21=8 => 20=8',
#  '16=5 & 22=1 => 20=8',
#  '16=5 & 23=1 => 20=8',
#  '16=5 & 24=1 => 20=8',
#  '18=6 => 20=8',
#  '19=3 => 20=8',
#  '21=8 => 20=8',
#  '22=1 => 20=8',
#  '23=1 => 20=8',
#  '24=1 => 20=8',
#  '25=n0_1 => 20=8',
#  '26=n0_2 => 20=8',
#  '27=n0_3 => 20=8',
#  '28=n0_4 => 20=8',
#  '29=n0_5 => 20=8',
#  '30=n0_6 => 20=8',
#  '31=n0_7 => 20=8',
#  '32=n0_8 => 20=8',
#  '33=n1_1 => 20=8',
#  '34=n1_2 => 20=8',
#  '35=n1_3 => 20=8',
#  '36=n1_4 => 20=8',
#  '37=n1_5 => 20=8',
#  '38=n1_6 => 20=8',
#  '39=n1_7 => 20=8',
#  '16=5 & 20=1 => 21=6',
#  '17=8 => 21=6',
#  '17=8 & 20=1 => 21=6',
#  '17=1 => 21=6',
#  '17=1 & 20=1 => 21=6',
#  '18=1 => 21=6',
#  '19=8 => 21=6',
#  '20=1 => 21=6',
#  '20=1 & 22=4 => 21=6',
#  '20=1 & 23=4 => 21=6',
#  '20=1 & 24=5 => 21=6',
#  '20=3 & 22=1 => 21=6',
#  '20=3 & 22=8 => 21=6',
#  '20=3 & 25=n0_1 => 21=6',
#  '20=3 & 26=n0_2 => 21=6',
#  '20=3 & 27=n0_3 => 21=6',
#  '20=3 & 28=n0_4 => 21=6',
#  '20=3 & 29=n0_5 => 21=6',
#  '20=3 & 30=n0_6 => 21=6',
#  '20=3 & 31=n0_7 => 21=6',
#  '20=3 & 32=n0_8 => 21=6',
#  '20=3 & 33=n1_1 => 21=6',
#  '20=3 & 34=n1_2 => 21=6',
#  '20=3 & 35=n1_3 => 21=6',
#  '20=3 & 36=n1_4 => 21=6',
#  '20=3 & 37=n1_5 => 21=6',
#  '20=3 & 38=n1_6 => 21=6',
#  '20=3 & 39=n1_7 => 21=6',
#  '22=4 => 21=6',
#  '23=3 => 21=6',
#  '23=4 & 25=n0_1 => 21=6',
#  '23=4 & 26=n0_2 => 21=6',
#  '23=4 & 27=n0_3 => 21=6',
#  '23=4 & 28=n0_4 => 21=6',
#  '23=4 & 29=n0_5 => 21=6',
#  '23=4 & 30=n0_6 => 21=6',
#  '23=4 & 31=n0_7 => 21=6',
#  '23=4 & 32=n0_8 => 21=6',
#  '23=4 & 33=n1_1 => 21=6',
#  '23=4 & 34=n1_2 => 21=6',
#  '23=4 & 35=n1_3 => 21=6',
#  '23=4 & 36=n1_4 => 21=6',
#  '23=4 & 37=n1_5 => 21=6',
#  '23=4 & 38=n1_6 => 21=6',
#  '23=4 & 39=n1_7 => 21=6',
#  '24=8 => 21=6',
#  '24=5 => 21=6',
#  '25=n0_1 => 21=6',
#  '26=n0_2 => 21=6',
#  '27=n0_3 => 21=6',
#  '28=n0_4 => 21=6',
#  '29=n0_5 => 21=6',
#  '30=n0_6 => 21=6',
#  '31=n0_7 => 21=6',
#  '32=n0_8 => 21=6',
#  '33=n1_1 => 21=6',
#  '34=n1_2 => 21=6',
#  '35=n1_3 => 21=6',
#  '36=n1_4 => 21=6',
#  '37=n1_5 => 21=6',
#  '38=n1_6 => 21=6',
#  '39=n1_7 => 21=6',
#  '20=3 => 21=7',
#  '20=3 & 23=4 => 21=7',
#  '23=4 => 21=7',
#  '16=5 => 21=1',
#  '18=8 => 21=1',
#  '19=1 => 21=1',
#  '20=5 => 21=1',
#  '23=1 => 21=1',
#  '24=1 => 21=1',
#  '25=n0_1 => 21=1',
#  '26=n0_2 => 21=1',
#  '27=n0_3 => 21=1',
#  '28=n0_4 => 21=1',
#  '29=n0_5 => 21=1',
#  '30=n0_6 => 21=1',
#  '31=n0_7 => 21=1',
#  '32=n0_8 => 21=1',
#  '33=n1_1 => 21=1',
#  '34=n1_2 => 21=1',
#  '35=n1_3 => 21=1',
#  '36=n1_4 => 21=1',
#  '37=n1_5 => 21=1',
#  '38=n1_6 => 21=1',
#  '39=n1_7 => 21=1',
#  '16=5 => 21=8',
#  '16=5 & 22=1 => 21=8',
#  '18=6 => 21=8',
#  '19=3 => 21=8',
#  '20=8 => 21=8',
#  '20=1 & 22=1 => 21=8',
#  '22=1 => 21=8',
#  '23=1 => 21=8',
#  '24=1 => 21=8',
#  '25=n0_1 => 21=8',
#  '26=n0_2 => 21=8',
#  '27=n0_3 => 21=8',
#  '28=n0_4 => 21=8',
#  '29=n0_5 => 21=8',
#  '30=n0_6 => 21=8',
#  '31=n0_7 => 21=8',
#  '32=n0_8 => 21=8',
#  '33=n1_1 => 21=8',
#  '34=n1_2 => 21=8',
#  '35=n1_3 => 21=8',
#  '36=n1_4 => 21=8',
#  '37=n1_5 => 21=8',
#  '38=n1_6 => 21=8',
#  '39=n1_7 => 21=8',
#  '18=6 => 22=1',
#  '19=3 => 22=1',
#  '20=8 => 22=1',
#  '20=3 => 22=1',
#  '20=3 & 21=6 => 22=1',
#  '20=3 & 23=8 => 22=1',
#  '20=3 & 24=4 => 22=1',
#  '20=3 & 25=n0_1 => 22=1',
#  '20=3 & 26=n0_2 => 22=1',
#  '20=3 & 27=n0_3 => 22=1',
#  '20=3 & 28=n0_4 => 22=1',
#  '20=3 & 29=n0_5 => 22=1',
#  '20=3 & 30=n0_6 => 22=1',
#  '20=3 & 31=n0_7 => 22=1',
#  '20=3 & 32=n0_8 => 22=1',
#  '20=3 & 33=n1_1 => 22=1',
#  '20=3 & 34=n1_2 => 22=1',
#  '20=3 & 35=n1_3 => 22=1',
#  '20=3 & 36=n1_4 => 22=1',
#  '20=3 & 37=n1_5 => 22=1',
#  '20=3 & 38=n1_6 => 22=1',
#  '20=3 & 39=n1_7 => 22=1',
#  '21=8 => 22=1',
#  '21=7 & 25=n0_1 => 22=1',
#  '21=7 & 26=n0_2 => 22=1',
#  '21=7 & 27=n0_3 => 22=1',
#  '21=7 & 28=n0_4 => 22=1',
#  '21=7 & 29=n0_5 => 22=1',
#  '21=7 & 30=n0_6 => 22=1',
#  '21=7 & 31=n0_7 => 22=1',
#  '21=7 & 32=n0_8 => 22=1',
#  '21=7 & 33=n1_1 => 22=1',
#  '21=7 & 34=n1_2 => 22=1',
#  '21=7 & 35=n1_3 => 22=1',
#  '21=7 & 36=n1_4 => 22=1',
#  '21=7 & 37=n1_5 => 22=1',
#  '21=7 & 38=n1_6 => 22=1',
#  '21=7 & 39=n1_7 => 22=1',
#  '23=1 => 22=1',
#  '23=3 => 22=1',
#  '24=1 => 22=1',
#  '24=8 => 22=1',
#  '25=n0_1 => 22=1',
#  '26=n0_2 => 22=1',
#  '27=n0_3 => 22=1',
#  '28=n0_4 => 22=1',
#  '29=n0_5 => 22=1',
#  '30=n0_6 => 22=1',
#  '31=n0_7 => 22=1',
#  '32=n0_8 => 22=1',
#  '33=n1_1 => 22=1',
#  '34=n1_2 => 22=1',
#  '35=n1_3 => 22=1',
#  '36=n1_4 => 22=1',
#  '37=n1_5 => 22=1',
#  '38=n1_6 => 22=1',
#  '39=n1_7 => 22=1',
#  '18=6 & 23=4 => 22=8',
#  '18=6 & 24=5 => 22=8',
#  '19=3 & 23=4 => 22=8',
#  '19=3 & 24=5 => 22=8',
#  '20=8 & 23=4 => 22=8',
#  '20=8 & 24=5 => 22=8',
#  '20=3 & 21=6 => 22=8',
#  '20=3 & 25=n0_1 => 22=8',
#  '20=3 & 26=n0_2 => 22=8',
#  '20=3 & 27=n0_3 => 22=8',
#  '20=3 & 28=n0_4 => 22=8',
#  '20=3 & 29=n0_5 => 22=8',
#  '20=3 & 30=n0_6 => 22=8',
#  '20=3 & 31=n0_7 => 22=8',
#  '20=3 & 32=n0_8 => 22=8',
#  '20=3 & 33=n1_1 => 22=8',
#  '20=3 & 34=n1_2 => 22=8',
#  '20=3 & 35=n1_3 => 22=8',
#  '20=3 & 36=n1_4 => 22=8',
#  '20=3 & 37=n1_5 => 22=8',
#  '20=3 & 38=n1_6 => 22=8',
#  '20=3 & 39=n1_7 => 22=8',
#  '21=8 & 23=4 => 22=8',
#  '21=8 & 24=5 => 22=8',
#  '23=3 => 22=8',
#  '24=8 => 22=8',
#  '25=n0_1 => 22=8',
#  '26=n0_2 => 22=8',
#  '27=n0_3 => 22=8',
#  '28=n0_4 => 22=8',
#  '29=n0_5 => 22=8',
#  '30=n0_6 => 22=8',
#  '31=n0_7 => 22=8',
#  '32=n0_8 => 22=8',
#  '33=n1_1 => 22=8',
#  '34=n1_2 => 22=8',
#  '35=n1_3 => 22=8',
#  '36=n1_4 => 22=8',
#  '37=n1_5 => 22=8',
#  '38=n1_6 => 22=8',
#  '39=n1_7 => 22=8',
#  '16=5 => 22=4',
#  '16=5 & 21=6 => 22=4',
#  '16=5 & 23=4 => 22=4',
#  '17=8 => 22=4',
#  '17=1 => 22=4',
#  '18=1 => 22=4',
#  '18=8 & 23=4 => 22=4',
#  '19=8 => 22=4',
#  '19=1 & 23=4 => 22=4',
#  '20=1 => 22=4',
#  '20=1 & 21=6 => 22=4',
#  '20=1 & 23=4 => 22=4',
#  '20=5 & 23=4 => 22=4',
#  '21=6 => 22=4',
#  '21=6 & 23=4 => 22=4',
#  '21=1 & 23=4 => 22=4',
#  '23=4 => 22=4',
#  '23=4 & 25=n0_1 => 22=4',
#  '23=4 & 26=n0_2 => 22=4',
#  '23=4 & 27=n0_3 => 22=4',
#  '23=4 & 28=n0_4 => 22=4',
#  '23=4 & 29=n0_5 => 22=4',
#  '23=4 & 30=n0_6 => 22=4',
#  '23=4 & 31=n0_7 => 22=4',
#  '23=4 & 32=n0_8 => 22=4',
#  '23=4 & 33=n1_1 => 22=4',
#  '23=4 & 34=n1_2 => 22=4',
#  '23=4 & 35=n1_3 => 22=4',
#  '23=4 & 36=n1_4 => 22=4',
#  '23=4 & 37=n1_5 => 22=4',
#  '23=4 & 38=n1_6 => 22=4',
#  '23=4 & 39=n1_7 => 22=4',
#  '24=5 => 22=4',
#  '25=n0_1 => 22=4',
#  '26=n0_2 => 22=4',
#  '27=n0_3 => 22=4',
#  '28=n0_4 => 22=4',
#  '29=n0_5 => 22=4',
#  '30=n0_6 => 22=4',
#  '31=n0_7 => 22=4',
#  '32=n0_8 => 22=4',
#  '33=n1_1 => 22=4',
#  '34=n1_2 => 22=4',
#  '35=n1_3 => 22=4',
#  '36=n1_4 => 22=4',
#  '37=n1_5 => 22=4',
#  '38=n1_6 => 22=4',
#  '39=n1_7 => 22=4',
#  '16=5 => 23=1',
#  '16=5 & 22=1 => 23=1',
#  '18=6 => 23=1',
#  '18=6 & 22=1 => 23=1',
#  '18=8 => 23=1',
#  '18=8 & 22=1 => 23=1',
#  '19=3 => 23=1',
#  '19=3 & 22=1 => 23=1',
#  '19=1 => 23=1',
#  '19=1 & 22=1 => 23=1',
#  '20=8 => 23=1',
#  '20=8 & 22=1 => 23=1',
#  '20=1 & 22=1 => 23=1',
#  '20=5 => 23=1',
#  '20=5 & 22=1 => 23=1',
#  '21=8 => 23=1',
#  '21=8 & 22=1 => 23=1',
#  '21=1 => 23=1',
#  '21=1 & 22=1 => 23=1',
#  '22=1 => 23=1',
#  '24=1 => 23=1',
#  '25=n0_1 => 23=1',
#  '26=n0_2 => 23=1',
#  '27=n0_3 => 23=1',
#  '28=n0_4 => 23=1',
#  '29=n0_5 => 23=1',
#  '30=n0_6 => 23=1',
#  '31=n0_7 => 23=1',
#  '32=n0_8 => 23=1',
#  '33=n1_1 => 23=1',
#  '34=n1_2 => 23=1',
#  '35=n1_3 => 23=1',
#  '36=n1_4 => 23=1',
#  '37=n1_5 => 23=1',
#  '38=n1_6 => 23=1',
#  '39=n1_7 => 23=1',
#  '20=3 => 23=3',
#  '20=3 & 21=6 => 23=3',
#  '20=3 & 22=1 => 23=3',
#  '20=3 & 22=8 => 23=3',
#  '20=3 & 25=n0_1 => 23=3',
#  '20=3 & 26=n0_2 => 23=3',
#  '20=3 & 27=n0_3 => 23=3',
#  '20=3 & 28=n0_4 => 23=3',
#  '20=3 & 29=n0_5 => 23=3',
#  '20=3 & 30=n0_6 => 23=3',
#  '20=3 & 31=n0_7 => 23=3',
#  '20=3 & 32=n0_8 => 23=3',
#  '20=3 & 33=n1_1 => 23=3',
#  '20=3 & 34=n1_2 => 23=3',
#  '20=3 & 35=n1_3 => 23=3',
#  '20=3 & 36=n1_4 => 23=3',
#  '20=3 & 37=n1_5 => 23=3',
#  '20=3 & 38=n1_6 => 23=3',
#  '20=3 & 39=n1_7 => 23=3',
#  '21=6 => 23=3',
#  '21=6 & 22=1 => 23=3',
#  '21=6 & 22=8 => 23=3',
#  '21=7 & 22=1 => 23=3',
#  '21=7 & 25=n0_1 => 23=3',
#  '21=7 & 26=n0_2 => 23=3',
#  '21=7 & 27=n0_3 => 23=3',
#  '21=7 & 28=n0_4 => 23=3',
#  '21=7 & 29=n0_5 => 23=3',
#  '21=7 & 30=n0_6 => 23=3',
#  '21=7 & 31=n0_7 => 23=3',
#  '21=7 & 32=n0_8 => 23=3',
#  '21=7 & 33=n1_1 => 23=3',
#  '21=7 & 34=n1_2 => 23=3',
#  '21=7 & 35=n1_3 => 23=3',
#  '21=7 & 36=n1_4 => 23=3',
#  '21=7 & 37=n1_5 => 23=3',
#  '21=7 & 38=n1_6 => 23=3',
#  '21=7 & 39=n1_7 => 23=3',
#  '22=1 => 23=3',
#  '22=8 => 23=3',
#  '24=8 => 23=3',
#  '25=n0_1 => 23=3',
#  '26=n0_2 => 23=3',
#  '27=n0_3 => 23=3',
#  '28=n0_4 => 23=3',
#  '29=n0_5 => 23=3',
#  '30=n0_6 => 23=3',
#  '31=n0_7 => 23=3',
#  '32=n0_8 => 23=3',
#  '33=n1_1 => 23=3',
#  '34=n1_2 => 23=3',
#  '35=n1_3 => 23=3',
#  '36=n1_4 => 23=3',
#  '37=n1_5 => 23=3',
#  '38=n1_6 => 23=3',
#  '39=n1_7 => 23=3',
#  '24=4 => 23=8',
#  '25=n0_1 => 23=8',
#  '26=n0_2 => 23=8',
#  '27=n0_3 => 23=8',
#  '28=n0_4 => 23=8',
#  '29=n0_5 => 23=8',
#  '30=n0_6 => 23=8',
#  '31=n0_7 => 23=8',
#  '32=n0_8 => 23=8',
#  '33=n1_1 => 23=8',
#  '34=n1_2 => 23=8',
#  '35=n1_3 => 23=8',
#  '36=n1_4 => 23=8',
#  '37=n1_5 => 23=8',
#  '38=n1_6 => 23=8',
#  '39=n1_7 => 23=8',
#  '16=5 & 21=6 => 23=4',
#  '17=8 => 23=4',
#  '17=1 => 23=4',
#  '18=1 => 23=4',
#  '19=8 => 23=4',
#  '20=1 => 23=4',
#  '20=1 & 21=6 => 23=4',
#  '21=7 => 23=4',
#  '22=4 => 23=4',
#  '24=5 => 23=4',
#  '16=5 => 24=5',
#  '16=5 & 21=6 => 24=5',
#  '16=5 & 23=4 => 24=5',
#  '17=8 => 24=5',
#  '17=8 & 23=4 => 24=5',
#  '17=1 => 24=5',
#  '17=1 & 23=4 => 24=5',
#  '18=6 & 23=4 => 24=5',
#  '18=1 => 24=5',
#  '18=1 & 23=4 => 24=5',
#  '18=8 & 23=4 => 24=5',
#  '19=3 & 23=4 => 24=5',
#  '19=8 => 24=5',
#  '19=8 & 23=4 => 24=5',
#  '19=1 & 23=4 => 24=5',
#  '20=8 & 23=4 => 24=5',
#  '20=1 => 24=5',
#  '20=1 & 21=6 => 24=5',
#  '20=1 & 23=4 => 24=5',
#  '20=5 & 23=4 => 24=5',
#  '21=8 & 23=4 => 24=5',
#  '21=6 => 24=5',
#  '21=6 & 23=4 => 24=5',
#  '21=1 & 23=4 => 24=5',
#  '22=8 & 23=4 => 24=5',
#  '22=4 => 24=5',
#  '22=4 & 23=4 => 24=5',
#  '23=4 => 24=5',
#  '23=4 & 25=n0_1 => 24=5',
#  '23=4 & 26=n0_2 => 24=5',
#  '23=4 & 27=n0_3 => 24=5',
#  '23=4 & 28=n0_4 => 24=5',
#  '23=4 & 29=n0_5 => 24=5',
#  '23=4 & 30=n0_6 => 24=5',
#  '23=4 & 31=n0_7 => 24=5',
#  '23=4 & 32=n0_8 => 24=5',
#  '23=4 & 33=n1_1 => 24=5',
#  '23=4 & 34=n1_2 => 24=5',
#  '23=4 & 35=n1_3 => 24=5',
#  '23=4 & 36=n1_4 => 24=5',
#  '23=4 & 37=n1_5 => 24=5',
#  '23=4 & 38=n1_6 => 24=5',
#  '23=4 & 39=n1_7 => 24=5',
#  '25=n0_1 => 24=5',
#  '26=n0_2 => 24=5',
#  '27=n0_3 => 24=5',
#  '28=n0_4 => 24=5',
#  '29=n0_5 => 24=5',
#  '30=n0_6 => 24=5',
#  '31=n0_7 => 24=5',
#  '32=n0_8 => 24=5',
#  '33=n1_1 => 24=5',
#  '34=n1_2 => 24=5',
#  '35=n1_3 => 24=5',
#  '36=n1_4 => 24=5',
#  '37=n1_5 => 24=5',
#  '38=n1_6 => 24=5',
#  '39=n1_7 => 24=5',
#  '16=5 => 24=1',
#  '16=5 & 22=1 => 24=1',
#  '18=6 => 24=1',
#  '18=6 & 22=1 => 24=1',
#  '18=8 => 24=1',
#  '18=8 & 22=1 => 24=1',
#  '19=3 => 24=1',
#  '19=3 & 22=1 => 24=1',
#  '19=1 => 24=1',
#  '19=1 & 22=1 => 24=1',
#  '20=8 => 24=1',
#  '20=8 & 22=1 => 24=1',
#  '20=1 & 22=1 => 24=1',
#  '20=5 => 24=1',
#  '20=5 & 22=1 => 24=1',
#  '21=8 => 24=1',
#  '21=8 & 22=1 => 24=1',
#  '21=1 => 24=1',
#  '21=1 & 22=1 => 24=1',
#  '22=1 => 24=1',
#  '23=1 => 24=1',
#  '25=n0_1 => 24=1',
#  '26=n0_2 => 24=1',
#  '27=n0_3 => 24=1',
#  '28=n0_4 => 24=1',
#  '29=n0_5 => 24=1',
#  '30=n0_6 => 24=1',
#  '31=n0_7 => 24=1',
#  '32=n0_8 => 24=1',
#  '33=n1_1 => 24=1',
#  '34=n1_2 => 24=1',
#  '35=n1_3 => 24=1',
#  '36=n1_4 => 24=1',
#  '37=n1_5 => 24=1',
#  '38=n1_6 => 24=1',
#  '39=n1_7 => 24=1',
#  '20=3 => 24=8',
#  '20=3 & 21=6 => 24=8',
#  '20=3 & 22=1 => 24=8',
#  '20=3 & 22=8 => 24=8',
#  '20=3 & 25=n0_1 => 24=8',
#  '20=3 & 26=n0_2 => 24=8',
#  '20=3 & 27=n0_3 => 24=8',
#  '20=3 & 28=n0_4 => 24=8',
#  '20=3 & 29=n0_5 => 24=8',
#  '20=3 & 30=n0_6 => 24=8',
#  '20=3 & 31=n0_7 => 24=8',
#  '20=3 & 32=n0_8 => 24=8',
#  '20=3 & 33=n1_1 => 24=8',
#  '20=3 & 34=n1_2 => 24=8',
#  '20=3 & 35=n1_3 => 24=8',
#  '20=3 & 36=n1_4 => 24=8',
#  '20=3 & 37=n1_5 => 24=8',
#  '20=3 & 38=n1_6 => 24=8',
#  '20=3 & 39=n1_7 => 24=8',
#  '21=6 => 24=8',
#  '21=6 & 22=1 => 24=8',
#  '21=6 & 22=8 => 24=8',
#  '21=7 & 22=1 => 24=8',
#  '21=7 & 25=n0_1 => 24=8',
#  '21=7 & 26=n0_2 => 24=8',
#  '21=7 & 27=n0_3 => 24=8',
#  '21=7 & 28=n0_4 => 24=8',
#  '21=7 & 29=n0_5 => 24=8',
#  '21=7 & 30=n0_6 => 24=8',
#  '21=7 & 31=n0_7 => 24=8',
#  '21=7 & 32=n0_8 => 24=8',
#  '21=7 & 33=n1_1 => 24=8',
#  '21=7 & 34=n1_2 => 24=8',
#  '21=7 & 35=n1_3 => 24=8',
#  '21=7 & 36=n1_4 => 24=8',
#  '21=7 & 37=n1_5 => 24=8',
#  '21=7 & 38=n1_6 => 24=8',
#  '21=7 & 39=n1_7 => 24=8',
#  '22=1 => 24=8',
#  '22=8 => 24=8',
#  '23=3 => 24=8',
#  '25=n0_1 => 24=8',
#  '26=n0_2 => 24=8',
#  '27=n0_3 => 24=8',
#  '28=n0_4 => 24=8',
#  '29=n0_5 => 24=8',
#  '30=n0_6 => 24=8',
#  '31=n0_7 => 24=8',
#  '32=n0_8 => 24=8',
#  '33=n1_1 => 24=8',
#  '34=n1_2 => 24=8',
#  '35=n1_3 => 24=8',
#  '36=n1_4 => 24=8',
#  '37=n1_5 => 24=8',
#  '38=n1_6 => 24=8',
#  '39=n1_7 => 24=8',
#  '23=8 => 24=4',
#  '25=n0_1 => 24=4',
#  '26=n0_2 => 24=4',
#  '27=n0_3 => 24=4',
#  '28=n0_4 => 24=4',
#  '29=n0_5 => 24=4',
#  '30=n0_6 => 24=4',
#  '31=n0_7 => 24=4',
#  '32=n0_8 => 24=4',
#  '33=n1_1 => 24=4',
#  '34=n1_2 => 24=4',
#  '35=n1_3 => 24=4',
#  '36=n1_4 => 24=4',
#  '37=n1_5 => 24=4',
#  '38=n1_6 => 24=4',
#  '39=n1_7 => 24=4',
#  '16=5 => 25=n0_1',
#  '17=8 => 25=n0_1',
#  '17=1 => 25=n0_1',
#  '18=6 => 25=n0_1',
#  '18=1 => 25=n0_1',
#  '18=8 => 25=n0_1',
#  '19=3 => 25=n0_1',
#  '19=8 => 25=n0_1',
#  '19=1 => 25=n0_1',
#  '20=8 => 25=n0_1',
#  '20=1 => 25=n0_1',
#  '20=5 => 25=n0_1',
#  '21=8 => 25=n0_1',
#  '21=6 => 25=n0_1',
#  '21=1 => 25=n0_1',
#  '22=1 => 25=n0_1',
#  '22=8 => 25=n0_1',
#  '22=4 => 25=n0_1',
#  '23=1 => 25=n0_1',
#  '23=3 => 25=n0_1',
#  '23=8 => 25=n0_1',
#  '24=1 => 25=n0_1',
#  '24=8 => 25=n0_1',
#  '24=4 => 25=n0_1',
#  '24=5 => 25=n0_1',
#  '26=n0_2 => 25=n0_1',
#  '27=n0_3 => 25=n0_1',
#  '28=n0_4 => 25=n0_1',
#  '29=n0_5 => 25=n0_1',
#  '30=n0_6 => 25=n0_1',
#  '31=n0_7 => 25=n0_1',
#  '32=n0_8 => 25=n0_1',
#  '33=n1_1 => 25=n0_1',
#  '34=n1_2 => 25=n0_1',
#  '35=n1_3 => 25=n0_1',
#  '36=n1_4 => 25=n0_1',
#  '37=n1_5 => 25=n0_1',
#  '38=n1_6 => 25=n0_1',
#  '39=n1_7 => 25=n0_1',
#  ...)

# %%
-_-
# Out:
#   File "<ipython-input-29-dcbbf4dfb535>", line 1
#     -_-
#        ^
# SyntaxError: invalid syntax
